# %%
#1questão
salario=float(input('Seu salário atual é: R$'))
print('salário atual é : R$',salario)
print('salário com acréscimo : R$', salario*1.25)

# %%
#2questão
salario=float(input('Seu salário atual é: R$'))
print('salário atual é : R$',salario)
print('acréscimo de : R$',salario*0.25)
print('salário com acréscimo : R$', salario*1.25)
# Out:
# Seu salário atual é: R$1000
# salário atual é : R$ 1000.0
# acréscimo de : R$ 250.0
# salário com acréscimo : R$ 1250.0

# %%
#3questão
atual= int(input('o ano atual é : '))
nascimento= int(input('o ano de nascimento é :'))
idade= atual - nascimento
print('Idade',idade)
print('Idade em mêses', idade*12)
print('Idade em dias',idade*365)
print('Idade em semanas',idade*52.143)
# Out:
# o ano atual é : 200
# o ano de nacimento é :25
# Idade 175
# Idade em mêses 2100
# Idade em dias 63875
# Idade em semanas 9125.025

# %%
#4questão
peso_saco=float(input('Quantidade do saco em KG:'))
peso01=float(input('Quantidade de ração do primeiro gato em Gramas:'))
peso02=float(input('Quantidade de ração do segundo gato em Gramas: '))
peso01=peso01/1000
peso02=peso02/1000
total=peso_saco - 5 * (peso01+peso02);
print('Total da ração restante em (KG):'),(float(total))

# %%
#5questão
a=float(input('Digite o 1° valor :'))
b=float(input('Digite o 2° valor :'))
print('1° valor :' ,b )
print('2° valor :',a )

# %%
#6questão
comprimento=float(input('Digite o comprimento da caixa retangolo:'))
largura=float(input('Digite a largura da caixa retangulo:'))
altura=float(input('Digite a altura da caixa retangulo:'))
print('Volume da caixa retangulo',comprimento*largura*altura)

# %%
1#7questão
a=float(input('Digite o 1° valor:'))
b=float(input('Digite o 2° valor:'))
r=(a-b)**2
print(r)
# Out:
# Digite o 1° valor:120
# Digite o 2° valor:2
# 13924.0

# %%
#8questão
dola=float(input('Digite a quantidade em dólares (UR$):'))
cotaçao=float(input('Cotação do dola (US$):'))
print('Resutado da transformação de (UR$) em (R$):',dola*cotaçao)

# %%
#9

a = float(input('Digite o 1° valor: '))
b = float(input('Digite o 2° valor: '))
c = float(input('Digite o 3° valor: '))

r = (a+b+c)**2
print(r)

# %%
#10
a=float(input('Digite o 1° valor: '))
b=float(input('Digite o 2° valor:'))
so=a+b
su=a-b
mul=a*b
div=a/b
print(so)
print(su)
print(mul)
print(div)
# Out:
# digire o valor 12
# digite o 2° valor13
# 25.0
# -1.0
# 156.0
# 0.9230769230769231

# %%
#11
r=float(input('Digite o raio :'))
t=float((4/3)*3.14159* r)
print(t)
# Out:
# Digite o raio :8
# 33.51029333333333

# %%
#12
a = float(input('Digite o valor: '))

s = a+1
an = a-1
print(s)
print(an)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-adfb8396b4a6> in <module>
#       1 #12
# ----> 2 a = float(input('Digite o valor: '))
#       3
#       4 s = a+1
#       5 an = a-1
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
# ...

# %%
#13
